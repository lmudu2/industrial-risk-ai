# %% [markdown]
# # Industrial Risk AI - Native Colab Deployment
#
# This dashboard provides predictive maintenance insights and industrial risk analysis. It uses a **FastAPI backend** and a **Streamlit frontend**.
#
# ### 🚀 Instructions
# 1. Click **Runtime > Run All**.
# 2. Wait for the environment to set up (cloning, installing, and generating data).
# 3. Click the **Dashboard Ready** link that appears at the bottom.

# %%
# --- 1. SETUP & REPO CLONING ---
import os
import time
import socket
from google.colab import output

# Cleanup old sessions
# !fuser -k 8501/tcp
# !fuser -k 8000/tcp
# !rm -rf industrial-risk-ai
# !git clone https://github.com/lmudu2/industrial-risk-ai.git
# %cd industrial-risk-ai
# !pip install -r requirements.txt --quiet

# Generate Industrial Data
# !python data/generate_data.py

# --- 2. START SERVICES ---
def wait_for_port(port, timeout=30):
    start_time = time.time()
    while time.time() - start_time < timeout:
        with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:
            if s.connect_ex(("localhost", port)) == 0: return True
        time.sleep(1)
    return False

# Launch Backend (FastAPI) on Port 8000
get_ipython().system_raw("uvicorn backend.main:app --host 0.0.0.0 --port 8000 &")

# Launch Frontend (Streamlit) on Port 8501
get_ipython().system_raw("streamlit run frontend/app.py --server.port 8501 --server.enableCORS False --server.headless True &")

if wait_for_port(8501):
    print("\n🚀 DASHBOARD READY!")
    print("Click the link below to open the Platform:")
    display(output.eval_js(f"google.colab.kernel.proxyPort(8501)"))
else:
    print("\n❌ Error: Dashboard failed to start.")
